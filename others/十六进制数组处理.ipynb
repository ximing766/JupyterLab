# %% [markdown]
# # 添加0x

# %%
hex_str = "..."

# 将十六进制字符串转换为0x格式的数组
hex_array = []
for i in range(0, len(hex_str), 2):
    hex_byte = hex_str[i:i+2]
    hex_array.append(f"0x{hex_byte}")

# 或者直接生成一行代码格式
array_str = "[" + ", ".join(hex_array) + "]"
print(f"\nhex_array = {array_str}")

# 计算累加和
sum_total = 0
for i in range(0, len(hex_str), 2):
    hex_byte = hex_str[i:i+2]
    byte_value = int(hex_byte, 16)  # 将十六进制转换为十进制
    sum_total += byte_value

print(f"\n累加和（十进制）: {sum_total}")
print(f"累加和（十六进制）: 0x{sum_total:X}")
# Out:
# hex_array = [, 0
# ...

# %% [markdown]
# # 字符串去空格

# %%
str_data = "0000FF66 0106FFFF FFFFFF05 FFFFFFFF FF19C200 061E006F 1A840E32 5041592E 5359532E 44444630 31A5089F 08023130"
str_data = str_data.replace(" ","") 
str_data
# Out:
# '0000FF660106FFFFFFFFFF05FFFFFFFFFF19C200061E006F1A840E325041592E5359532E4444463031A5089F08023130'
