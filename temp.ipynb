# %%
import subprocess
subprocess.Popen("")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import subprocess
# ----> 2 subprocess.Popen("Excel")
#
# File d:\ISoftware\anaconda\router\envs\pyqt6\Lib\subprocess.py:1028, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1024         if self.text_mode:
#    1025             self.stderr = io.TextIOWrapper(self.stderr,
#    1026                     encoding=encoding, errors=errors)
# -> 1028     self._execute_child(args, executable, preexec_fn, close_fds,
#    1029                         pass_fds, cwd, env,
#    1030                         startupinfo, creationflags, shell,
# ...

# %%
import os
print(os.environ.get('PATH'))
# Out:
# d:\ISoftware\anaconda\router\envs\pyqt6;c:\Users\16379\AppData\Local\Programs\cursor\resources\app\bin;C:\Perl64\site\bin;C:\Perl64\bin;C:\Program Files (x86)\Common Files\Oracle\Java\java8path;C:\Program Files (x86)\Common Files\Oracle\Java\javapath;C:\NXP\DK6ProductionFlashProgrammer\;C:\Users\16379\AppData\Local\Programs\Python\Python312;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0\;C:\Windows\System32\OpenSSH\;C:\Program Files\dotnet\;E:\Work\UWB\download\JN-SW-4407_DK6_Production\JCShell\;C:\Program Files\Java\jdk1.8.0_291\bin;C:\Program Files\Java\jdk1.8.0_291\jre\bin;C:\Program Files\Git\cmd;C:\MinGW\bin;C:\Program Files\CMake\bin;D:\ISoftware\adb\platform-tools;D:\ISoftware\anaconda\router\Scripts;D:\ISoftware\anaconda\router\Library\bin;C:\Users\16379\AppData\Local\activestate\cache\bin;C:\Users\16379\scoop\shims;C:\Users\16379\AppData\Local\Microsoft\WindowsApps;C:\Program Files\7-Zip;C:\Users\16379\AppData\Local\GitHubD
# ...
